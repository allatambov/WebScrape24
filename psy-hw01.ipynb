# %% [markdown]
# # Домашнее задание 1
#
# *Алла Тамбовцева*
#
# ## Формат сдачи
#
# Задание выполняется самостоятельно. При любых нетривиальных совпадениях в решениях задач все вовлечённые домашние работы будут оценены на 0 баллов. Свой ipynb-файл с решением необходимо прислать до дедлайна на почту allatambov@gmail.com.

# %% [markdown]
# ## Задание
#
# Для описания фильма «31 июня» была создана небольшая HTML-страница, код для которой размещён в ячейке ниже:

# %% [markdown]
# <html>
#     <h2>31 июня (1978)</h2>
#     <h3>Аннотация</h3>
#     <p>Телефильм по мотивам повести Джона Б.Пристли.</p>
#     <p>Фантастическая история любви художника, живущего в XXI веке и принцессы королевства Перадор,
#         времён правления короля Артура.</p>
#     <p><i>Полная аннотация доступна
#        <a href="https://www.kino-teatr.ru/kino/movie/sov/27/annot/">
#        здесь</a>.</i></p>
#     <h3>О фильме</h3>
#     <ul>
#         <li>Режиссёр: Леонид Квинихидзе</li>
#         <li>Композитор: Александр Зацепин</li>
#         <li>Актёры: Наталия Трубникова, Николай Ерёменко (мл.), Владимир Зельдин, Владимир Этуш, Людмила Власова, Александр Годунов, Любовь Полищук, Игорь Ясулович, Марина Нудьга, Эммануил Геллер, Михаил Кокшенов, Владимир Сошальский</li>
#     </ul>
#     <h3>Характеристики</h3>
#     <table>
#         <tr><th></th><th>Значение</th></tr>
#         <tr><th>Рейтинг (Кинопоиск)</th><td>7.9</td></tr>
#         <tr><th>Рейтинг (Кино-Театр)</th><td>8.9</td></tr>
#     <tr></tr>
#     </table>
# </html>

# %% [markdown]
# Код HTML также хранится в переменной `text` в виде обычной строки:

# %%
text = """
<html>
    <h2>31 июня (1978)</h2>
    <h3>Аннотация</h3>
    <p>Телефильм по мотивам повести Джона Б.Пристли.</p>
    <p>Фантастическая история любви художника, живущего в XXI веке и принцессы королевства Перадор, 
        времён правления короля Артура.</p>
    <p><i>Полная аннотация доступна
       <a href="https://www.kino-teatr.ru/kino/movie/sov/27/annot/">
       здесь</a>.</i></p>
    <h3>О фильме</h3>
    <ul>
        <li>Режиссёр: Леонид Квинихидзе</li> 
        <li>Композитор: Александр Зацепин</li> 
        <li>Актёры: Наталия Трубникова, Николай Ерёменко (мл.), Владимир Зельдин, Владимир Этуш, Людмила Власова, Александр Годунов, Любовь Полищук, Игорь Ясулович, Марина Нудьга, Эммануил Геллер, Михаил Кокшенов, Владимир Сошальский</li>
    </ul>
    <h3>Характеристики</h3>
    <table>
        <tr><th></th><th>Значение</th></tr>
        <tr><th>Рейтинг (Кинопоиск)</th><td>7.9</td></tr>
        <tr><th>Рейтинг (Кино-Театр)</th><td>8.9</td></tr>
    <tr></tr>
    </table>
</html>
"""

# %% [markdown]
# ### Задача 1 (1 балл)
#
# Преобразуйте строку `text` в объект типа `BeautifulSoup` и сохраните его в переменную `soup`. В последующих задачах нужно будет выполнять поиск в рамках этого объекта.

# %%
### YOUR CODE HERE

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Сохраните в переменную `describe` аннотацию фильма и выведите её содержимое на экран. Аннотация должна содержать только тексты первых двух абзацев (без последней строки со ссылкой на сайт).

# %%
### YOUR CODE HERE

# %% [markdown]
# ### Задача 3 (2 балла)
#
# Сохраните в список `ratings` значения рейтинга фильма из разных источников. Все значения списка должны быть **числовыми** – типа `float`.

# %%
### YOUR CODE HERE

# %% [markdown]
# ### Задача 4 (1 балл)
#
# Вычислите на основе списка `ratings` средний рейтинг фильма и сохраните его в переменную `ave_rating`.

# %%
### YOUR CODE HERE

# %% [markdown]
# ### Задача 5 (4 балла)
#
# Используя элементы ненумерованного списка из раздела *О фильме*, создайте словарь такого вида:
#
#     {'Режиссёр': ' Леонид Квинихидзе',
#      'Композитор': ' Александр Зацепин',
#      'Актёры': ['Наталия Трубникова', 'Николай Ерёменко (мл.)', 'Владимир Зельдин',
#                  'Владимир Этуш', 'Людмила Власова', 'Александр Годунов', 'Любовь Полищук',
#                  'Игорь Ясулович', 'Марина Нудьга', 'Эммануил Геллер', 'Михаил Кокшенов',
#                  'Владимир Сошальский']}

# %%
### YOUR CODE HERE
