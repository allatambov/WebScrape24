# %% [markdown]
# ## Домашнее задание 5
#
# *Автор задач: Тамбовцева А.А.*
#
# ### Формат сдачи
#
# Задание выполняется самостоятельно. При любых нетривиальных совпадениях в решениях задач все вовлечённые домашние работы будут оценены на 0 баллов. Свой ipynb-файл с решением необходимо прислать до дедлайна на почту allatambov@gmail.com.

# %% [markdown]
# ### Задача 1 (2 балла)
#
# Используя возможности Selenium и BeautifulSoup, заберите со  [страницы](https://financesonline.com/number-of-gamers-worldwide/) сайта FinancesOnline следующую информацию из **первого графика**:
#
# * год;
# * число активных геймеров с 2015 по 2023 год.
#
# На выходе должен получиться датафрейм pandas со столбцом `year` (тип *integer*) и столбцом `n_gamers` (тип *float*).
#
# **Инструкция.** Найдите, используя методы на объектах Selenium, элемент, содержащий необходимые данные, извлеките из него исходный код HTML и выполните дальнейший поиск с помощью BeautifulSoup.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (3 балла)
#
# Используя возможности Selenium и BeautifulSoup, заберите с этой же страницы следующую информацию из раздела **Top 10 Countries By Gaming Revenue**:
#
# * название страны;
# * доход в 2020 году.
#
# На выходе должен получиться датафрейм pandas со столбцом `country` (тип *string*) и столбцом `revenue` (тип *float*).
#
# **Инструкция.** Алгоритм поиска похож на алгоритм из предыдущей задачи, но здесь добавляется сложность – столбцы с необходимыми значениями появляются на графике только тогда, когда мы скроллим страницу до него. Чтобы не выбирать значение, на которое нужно проскроллить страницу вниз «на глаз», можно воспользоваться значением из атрибута `.location`, который хранит координаты элемента на странице. Этот атрибут есть у всех объектов типа `webelement.WebElement`, то есть тех объектов, которые возвращаются по итогам применения методов `.find_element()` и `.find_elements()`. Для скроллинга до определённого места можно использовать код из практикума 6.2.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (2 балла)
#
# Используя возможности Selenium, зайдите на [страницу](https://www.proballers.com/basketball/league/177/euroleague) со статистикой баскетбольных матчей и проскролльте раздел с датами матчей до самой ранней даты (5 октября 2023 года).
#
# **Инструкция.** Так как кликать много раз на стрелку влево нерационально, можно найти элемент, содержащий необходимую информацию, и имитировать исполнение кода на JavaScript для скроллинга до определённого элемента. Искать координаты этого элемента необязательно, есть полезный скрипт:
#
#     br.execute_script("arguments[0].scrollIntoView()", element)
#
# Код выше позволяет выполнять скроллинг страницы таким образом, чтобы увидеть объект `element` (смысл `scrollIntoView()`). Поэтому вам необходимо найти элемент с нужной датой, сохранить его как `element` и исполнить данную строку кода.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (3 балла)
#
# Используя возможности Selenium, кликните на найденный ранее элемент с самой ранней датой (5 октября 2023 года). найдите контейнер (раздел `div`), содержащий информацию ТОЛЬКО по этой дате и извлеките из него исходный код HTML.
#
# Используя BeautifulSoup, извлеките из исходного кода следующую информацию:
#
# * время всех матчей в этой день;
# * пары из названий команд-противников на каждом матче;
# * пары из набранных каждой командой очков.
#
# Ожидаемый результат – датафрейм pandas со строками вида (пример первого матча):
#
#     7:00 PM (CEST)   CRV    ASV   94    73
#
# Время матчей и названия команд – строки, очки – целые числа.

# %%
### YOUR CODE HERE ###
