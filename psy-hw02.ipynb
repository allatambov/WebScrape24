# %% [markdown]
# # Домашнее задание 2
#
# *Автор задач: Тамбовцева А.А.*
#
# ## Формат сдачи
#
# Задание выполняется самостоятельно. При любых нетривиальных совпадениях в решениях задач все вовлечённые домашние работы будут оценены на 0 баллов. Свой ipynb-файл с решением необходимо прислать до дедлайна на почту allatambov@gmail.com.
#
# ## Задание
#
# Дана страница с описанием фильма «Не покидай...» на сайте КИНО-ТЕАТР.РУ. Ссылка на главную страницу фильма сохранена с переменной `main`, ссылка на страницу с актёрами – в переменной `titr`.
#
# Если вдруг возникают проблемы с доступом (при парсинге выдается не исходный код страницы, а пустая страница с сообщением о попытках автоматического подключения к странице), можете воспользоваться запасными ссылками `main` и `titr`, это ссылки на копии страниц в репозитории Github для нашего курса, они точно открываются.

# %%
main = "https://www.kino-teatr.ru/kino/movie/sov/4319/annot/"
titr = "https://www.kino-teatr.ru/kino/movie/sov/4319/titr/"

# %%
# запасные ссылки
main = "https://raw.githubusercontent.com/allatambov/WebScrape24/main/annot.html"
titr = "https://raw.githubusercontent.com/allatambov/WebScrape24/main/titr.html"

# %% [markdown]
# ### Задача 1 (1 балл)
#
# Используя возможности библиотек `requests` и `BeautifulSoup`, извлеките из страницы название фильма и его рейтинг. Сохраните их в переменные `film_name` (тип `string`) и `film_rating` (тип `float`) соответственно.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Сохраните в список `act_info` информацию об актёрах (в «сыром» виде, в виде объектов `BeautifulSoup`), которая хранится на карточке актёра.
#
# Для определённости – вот пример элемента такого списка:
#
# ```
# <div class="actor_details">
# <div class="actor_film_descript" id="role_16801">
# <div class="film_name"><a href="/kino/acter/w/sov/4484/bio/" itemprop="url" title="Лидия Федосеева-Шукшина"><strong itemprop="name">Лидия Федосеева-Шукшина</strong></a></div>
# <div class="film_role">Королева Флора — <span class="film_main_role">главная роль</span></div>
# <div class="film_role_descript">жена короля Теодора</div>
# <div class="film_rating"><span id="role_rating_16801"></span></div>
# </div>
# <div class="actor_film_screens"><a href="/kino/movie/sov/4319/foto/a4484/1162854/" title="Лидия Федосеева-Шукшина"><img alt="Лидия Федосеева-Шукшина" class="actor_film_img" src="/acter/photo/4/8/4484/pv_1162854.jpg" title="Лидия Федосеева-Шукшина"/></a></div>
# </div>
# ```
#
# Выберите только элементы с индексами от 0 до 33 включительно, сохраните изменения в том же списке. Если информация сгружена правильно, это все актёры без учета актёров дубляжа и каскадёров. Их труд очень ценен, особенно с учётом некоторых деталей съёмок, но для следующих задач нужен рейтинг, а его для актёров за кадром на сайте нет.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (3 балла)
#
# Напишите функцию `get_personal()`, которая принимает на вход элемент списка `act_info` и возвращает список из следующих характеристик:
#
# * id актёра (`role_16801` в примере выше);
# * ФИО актёра (`Лидия Федосеева-Шукшина` в примере выше);
# * роль (`Королева Флора — главная роль` в примере выше, пустая строка, если её нет);
# * описание роли (`жена короля Теодора` в примере выше, пустая строка, если его нет).
#
# Примените эту функцию ко всем элементам списка `act_info` и создайте новый список списков `L` такого вида:
#
# ```
# [['role_16801', 'Лидия Федосеева-Шукшина',
# 'Королева Флора — главная роль', 'жена короля Теодора'],
# ['role_16800', 'Вячеслав Невинный',
# 'Король Теодор — главная роль', ''],
# ...]
# ```
#
# Преобразуйте полученный список в датафрейм `main`, присвойте столбцам названия `id`, `name`, `role`, `desc`.
#
# **Подсказка:** если роль/её описание не найдены, используйте конструкцию `try-except`, чтобы в случае ошибки сохранять просто пустую строку. Разумно использовать эту конструкцию два раза, один `try-except` для роли, а второй – для её описания, так как необязательно эта информация отсутствует одновременно.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (2 балла)
#
# Дан список словарей, где каждый словарь содержит число лайков и дислайков, поставленных актёрам зарегистрированными пользователями сайта (просто так спарсить их из исходного кода не получится, значения обновляются динамически, это возможно, обсудим позже):

# %%
N = [{"id":"role_160325", "plus":"55", "minus":"2"}, {"id":"role_1928641", "plus":"28", "minus":"1"},
{"id":"role_1966145", "plus":"23", "minus":"1"}, {"id":"role_1973000", "plus":"23", "minus":"1"},
{"id":"role_1973001", "plus":"24", "minus":"1"}, {"id":"role_1973002", "plus":"25", "minus":"0"},
{"id":"role_1973003", "plus":"25", "minus":"1"}, {"id":"role_1973005", "plus":"25", "minus":"2"},
{"id":"role_1973007", "plus":"28", "minus":"1"}, {"id":"role_1973008", "plus":"22", "minus":"1"},
{"id":"role_1973010", "plus":"34", "minus":"5"}, {"id":"role_1973011", "plus":"46", "minus":"3"},
{"id":"role_2088754", "plus":"29", "minus":"2"}, {"id":"role_16800", "plus":"156", "minus":"4"},
{"id":"role_16801", "plus":"109", "minus":"26"}, {"id":"role_16803", "plus":"125", "minus":"12"},
{"id":"role_16802", "plus":"146", "minus":"8"}, {"id":"role_16804", "plus":"140", "minus":"6"},
{"id":"role_56008", "plus":"102", "minus":"10"}, {"id":"role_62460", "plus":"102", "minus":"4"},
{"id":"role_72744", "plus":"122", "minus":"3"}, {"id":"role_83813", "plus":"43", "minus":"2"},
{"id":"role_89473", "plus":"100", "minus":"21"}, {"id":"role_124124", "plus":"128", "minus":"7"},
{"id":"role_132138", "plus":"132", "minus":"2"}, {"id":"role_132139", "plus":"116", "minus":"5"},
{"id":"role_132140", "plus":"78", "minus":"3"}, {"id":"role_132141", "plus":"72", "minus":"6"}]

# %% [markdown]
# Создайте датафрейм `numbers` со следующими столбцами: `id`, `plus`, `minus`. Измените тип столбцов `plus` и `minus` на тип `integer`.
#
# **Подсказка:** для получения датафрейма в данном случае можно использовать ту же функцию, что и для получения датафрейма из списка списков (или списка кортежей).

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5 (1 балл)
#
# Добавьте в полученный ранее датафрейм `numbers` столбец `rating`, который представляет собой рейтинг актёра, вычисляемый как разность между числом лайков и дислайков.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6 (1 балл)
#
# Объедините датафреймы `main` и `numbers` по id актёров, назовите объединённый датафрейм `final`. Отсортируйте актёров по убыванию рейтинга, выберите первые 10 строк и выведите на экран.
#
# **Подсказка:** для объединения датафреймов используйте [метод](https://pandas.pydata.org/docs/reference/api/pandas.merge.html) `merge()` (способ объединения  в `how` менять не нужно, здесь мы смотрим на общие элементы, а значение *inner*  как раз соответствует пересечению множеств). Для сортировки строк используйте [метод](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html) `.sort_values()`.

# %%
### YOUR CODE HERE ###
